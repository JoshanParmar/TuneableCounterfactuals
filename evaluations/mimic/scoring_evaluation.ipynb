# %%
import sys

sys.path.append("../../src")

import pickle
from tuneable_counterfactuals_explainer.explainer import Explainer

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
model = pickle.load(open("model/model.pkl", "rb"))
training_data = pickle.load(open("model/train_X.pkl", "rb"))

# %%
training_data.columns
# Out:
# Index(['age', 'bmi', 'weight_first', 'icu_los_day', 'hospital_los_day',
#        'day_icu_intime_num', 'hour_icu_intime', 'map_1st', 'hr_1st',
#        'temp_1st', 'spo2_1st', 'abg_count', 'wbc_first', 'hgb_first',
#        'platelet_first', 'sodium_first', 'potassium_first', 'tco2_first',
#        'chloride_first', 'bun_first', 'creatinine_first', 'prediction',
#        'day_28_flg'],
#       dtype='object')

# %%
explainer = Explainer(
    model,
    training_data,
    "target",
    bounding_method="quantile",
    number_samples=20,
    changeability_scores={
        # 'bmi': 0.5,
        "weight_first": 0.5,
        "platelet_first": 1,
        # 'sodium_first': 1,
        # 'potassium_first':1,
        "tco2_first": 1,
        "chloride_first": 1,
        "creatinine_first": 1,
    },
)

# %%
res = explainer.explain(
    training_data.iloc[0],
    store_historical_explainers=True,
    # additional_threshold=0.45,
)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# 206it [00:02, 83.91it/s]
# All nodes in this graph have been searched

# %%
import graphviz

# %%
res
# Out:
# {(): 9.042861906878263e-05,
#  ('weight_first',): 7.175638760592074e-05,
#  ('platelet_first',): 0.002863131189964069,
#  ('tco2_first',): 0.00032398194956892104,
#  ('chloride_first',): 0.00019904045421525722,
#  ('creatinine_first',): 0.00016466249826343641,
#  ('platelet_first', 'weight_first'): 0.0011387710306409436,
#  ('platelet_first', 'tco2_first'): 0.014325008126373329,
#  ('platelet_first', 'chloride_first'): 0.007509208475529455,
#  ('platelet_first', 'creatinine_first'): 0.015019129499198872,
#  ('platelet_first', 'creatinine_first', 'weight_first'): 0.00650501543751181,
#  ('platelet_first', 'creatinine_first', 'tco2_first'): 0.16570695485004192,
#  ('platelet_first',
#   'creatinine_first',
#   'chloride_first'): 0.035634173449230616,
#  ('platelet_first',
#   'creatinine_first',
#   'tco2_first',
#   'weight_first'): 0.0658457896396117,
#  ('platelet_first',
#   'creatinine_first',
#   'tco2_first',
#   'chloride_first'): 0.38145822518474326,
#  ('platelet_first',
#   'creatinine_first',
#   'tco2_first',
#   'chloride_first',
#   'weight_first'): 0.21750517250991813,
#  ('platelet_first',
#   'creatinine_first',
#   'tco2_first',
#   'weight_first',
#   'chloride_first'): 0.21749984990337803,
#  ('platelet_first',
#   'creatinine_first',
#   'chloride_first',
#   'weight_first'): 0.21750517250991813,
#  ('platelet_first',
#   'creatinine_first',
#   'chloride_first',
#   'tco2_first'): 0.217430099431202,
#  ('platelet_first',
#   'creatinine_first',
#   'chloride_first',
#   'tco2_first',
#   'weight_first'): 0.21750517250991813,
#  ('platelet_first',
#   'creatinine_first',
#   'chloride_first',
#   'weight_first',
#   'tco2_first'): 0.217430099431202,
#  ('platelet_first',
#   'creatinine_first',
#   'weight_first',
#   'tco2_first'): 0.217430099431202,
#  ('platelet_first',
#   'creatinine_first',
#   'weight_first',
#   'chloride_first'): 0.21749984990337803,
#  ('platelet_first',
#   'creatinine_first',
#   'weight_first',
#   'tco2_first',
#   'chloride_first'): 0.21749984990337803,
#  ('platelet_first',
#   'creatinine_first',
#   'weight_first',
#   'chloride_first',
#   'tco2_first'): 0.217430099431202,
#  ('platelet_first', 'tco2_first', 'weight_first'): 0.21750517250991813,
#  ('platelet_first', 'tco2_first', 'chloride_first'): 0.21749984990337803,
#  ('platelet_first', 'tco2_first', 'creatinine_first'): 0.2174695807534544,
#  ('platelet_first',
#   'tco2_first',
#   'chloride_first',
#   'weight_first'): 0.030822679199130214,
#  ('platelet_first',
#   'tco2_first',
#   'chloride_first',
#   'creatinine_first'): 0.3815006413621993,
#  ('platelet_first',
#   'tco2_first',
#   'chloride_first',
#   'creatinine_first',
#   'weight_first'): 0.21750517250991813,
#  ('platelet_first',
#   'tco2_first',
#   'chloride_first',
#   'weight_first',
#   'creatinine_first'): 0.2174695807534544,
#  ('platelet_first',
#   'tco2_first',
#   'weight_first',
#   'chloride_first'): 0.21749984990337803,
#  ('platelet_first',
#   'tco2_first',
#   'weight_first',
#   'creatinine_first'): 0.2174695807534544,
#  ('platelet_first',
#   'tco2_first',
#   'weight_first',
#   'chloride_first',
#   'creatinine_first'): 0.2174695807534544,
#  ('platelet_first',
#   'tco2_first',
#   'weight_first',
#   'creatinine_first',
#   'chloride_first'): 0.21749984990337803,
#  ('platelet_first',
#   'tco2_first',
#   'creatinine_first',
#   'weight_first'): 0.21750517250991813,
#  ('platelet_first',
#   'tco2_first',
#   'creatinine_first',
#   'chloride_first'): 0.21749984990337803,
#  ('platelet_first',
#   'tco2_first',
#   'creatinine_first',
#   'chloride_first',
#   'weight_first'): 0.21750517250991813,
#  ('platelet_first',
#   'tco2_first',
#   'creatinine_first',
#   'weight_first',
#   'chloride_first'): 0.21749984990337803,
#  ('platelet_first', 'chloride_first', 'weight_first'): 0.21750517250991813,
#  ('platelet_first', 'chloride_first', 'tco2_first'): 0.217430099431202,
#  ('platelet_first', 'chloride_first', 'creatinine_first'): 0.2174695807534544,
#  ('platelet_first',
#   'chloride_first',
#   'tco2_first',
#   'weight_first'): 0.030822679199130214,
#  ('platelet_first',
#   'chloride_first',
#   'tco2_first',
#   'creatinine_first'): 0.3815006413621993,
#  ('platelet_first',
#   'chloride_first',
#   'tco2_first',
#   'creatinine_first',
#   'weight_first'): 0.21750517250991813,
#  ('platelet_first',
#   'chloride_first',
#   'tco2_first',
#   'weight_first',
#   'creatinine_first'): 0.2174695807534544,
#  ('platelet_first',
#   'chloride_first',
#   'weight_first',
#   'tco2_first'): 0.217430099431202,
#  ('platelet_first',
#   'chloride_first',
#   'weight_first',
#   'creatinine_first'): 0.2174695807534544,
#  ('platelet_first',
#   'chloride_first',
#   'weight_first',
#   'tco2_first',
#   'creatinine_first'): 0.2174695807534544,
#  ('platelet_first',
#   'chloride_first',
#   'weight_first',
#   'creatinine_first',
#   'tco2_first'): 0.217430099431202,
#  ('platelet_first',
#   'chloride_first',
#   'creatinine_first',
#   'weight_first'): 0.21750517250991813,
#  ('platelet_first',
#   'chloride_first',
#   'creatinine_first',
#   'tco2_first'): 0.217430099431202,
#  ('platelet_first',
#   'chloride_first',
#   'creatinine_first',
#   'tco2_first',
#   'weight_first'): 0.21750517250991813,
#  ('platelet_first',
#   'chloride_first',
#   'creatinine_first',
#   'weight_first',
#   'tco2_first'): 0.217430099431202,
#  ('platelet_first', 'weight_first', 'tco2_first'): 0.217430099431202,
#  ('platelet_first', 'weight_first', 'chloride_first'): 0.21749984990337803,
#  ('platelet_first', 'weight_first', 'creatinine_first'): 0.2174695807534544,
#  ('platelet_first',
#   'weight_first',
#   'tco2_first',
#   'chloride_first'): 0.030831078329680472,
#  ('platelet_first',
#   'weight_first',
#   'tco2_first',
#   'creatinine_first'): 0.06586838738128672,
#  ('platelet_first',
#   'weight_first',
#   'tco2_first',
#   'creatinine_first',
#   'chloride_first'): 0.21749984990337803,
#  ('platelet_first',
#   'weight_first',
#   'tco2_first',
#   'chloride_first',
#   'creatinine_first'): 0.2174695807534544,
#  ('platelet_first',
#   'weight_first',
#   'chloride_first',
#   'tco2_first'): 0.217430099431202,
#  ('platelet_first',
#   'weight_first',
#   'chloride_first',
#   'creatinine_first'): 0.2174695807534544,
#  ('platelet_first',
#   'weight_first',
#   'chloride_first',
#   'tco2_first',
#   'creatinine_first'): 0.2174695807534544,
#  ('platelet_first',
#   'weight_first',
#   'chloride_first',
#   'creatinine_first',
#   'tco2_first'): 0.217430099431202,
#  ('platelet_first',
#   'weight_first',
#   'creatinine_first',
#   'tco2_first'): 0.217430099431202,
#  ('platelet_first',
#   'weight_first',
#   'creatinine_first',
#   'chloride_first'): 0.21749984990337803,
#  ('platelet_first',
#   'weight_first',
#   'creatinine_first',
#   'tco2_first',
#   'chloride_first'): 0.21749984990337803,
#  ('platelet_first',
#   'weight_first',
#   'creatinine_first',
#   'chloride_first',
#   'tco2_first'): 0.217430099431202,
#  ('tco2_first', 'weight_first'): 0.21750517250991813,
#  ('tco2_first', 'platelet_first'): 0.21746014123794383,
#  ('tco2_first', 'chloride_first'): 0.21749984990337803,
#  ('tco2_first', 'creatinine_first'): 0.2174695807534544,
#  ('tco2_first', 'chloride_first', 'weight_first'): 0.0019463368927770917,
#  ('tco2_first', 'chloride_first', 'platelet_first'): 0.10580965551464167,
#  ('tco2_first', 'chloride_first', 'creatinine_first'): 0.0018230196904496375,
#  ('tco2_first',
#   'chloride_first',
#   'platelet_first',
#   'weight_first'): 0.030822679199130214,
#  ('tco2_first',
#   'chloride_first',
#   'platelet_first',
#   'creatinine_first'): 0.3815006413621993,
#  ('tco2_first',
#   'chloride_first',
#   'platelet_first',
#   'creatinine_first',
#   'weight_first'): 0.21750517250991813,
#  ('tco2_first',
#   'chloride_first',
#   'platelet_first',
#   'weight_first',
#   'creatinine_first'): 0.2174695807534544,
#  ('tco2_first',
#   'chloride_first',
#   'weight_first',
#   'platelet_first'): 0.21746014123794383,
#  ('tco2_first',
#   'chloride_first',
#   'weight_first',
#   'creatinine_first'): 0.2174695807534544,
#  ('tco2_first',
#   'chloride_first',
#   'weight_first',
#   'platelet_first',
#   'creatinine_first'): 0.19640036277660688,
#  ('tco2_first',
#   'chloride_first',
#   'weight_first',
#   'creatinine_first',
#   'platelet_first'): 0.19637517218348843,
#  ('tco2_first',
#   'chloride_first',
#   'creatinine_first',
#   'weight_first'): 0.21750517250991813,
#  ('tco2_first',
#   'chloride_first',
#   'creatinine_first',
#   'platelet_first'): 0.19637517218348843,
#  ('tco2_first',
#   'chloride_first',
#   'creatinine_first',
#   'weight_first',
#   'platelet_first'): 0.03792887133050398,
#  ('tco2_first',
#   'chloride_first',
#   'creatinine_first',
#   'platelet_first',
#   'weight_first'): 0.03792742815521153,
#  ('tco2_first', 'weight_first', 'platelet_first'): 0.03792887133050398,
#  ('tco2_first', 'weight_first', 'chloride_first'): 0.03792076873570897,
#  ('tco2_first', 'weight_first', 'creatinine_first'): 0.2174695807534544,
#  ('tco2_first',
#   'weight_first',
#   'creatinine_first',
#   'platelet_first'): 0.06584331541618448,
#  ('tco2_first',
#   'weight_first',
#   'creatinine_first',
#   'chloride_first'): 0.002116556614446923,
#  ('tco2_first',
#   'weight_first',
#   'creatinine_first',
#   'platelet_first',
#   'chloride_first'): 0.21749984990337803,
#  ('tco2_first',
#   'weight_first',
#   'creatinine_first',
#   'chloride_first',
#   'platelet_first'): 0.21746014123794383,
#  ('tco2_first',
#   'weight_first',
#   'chloride_first',
#   'platelet_first'): 0.21746014123794383,
#  ('tco2_first',
#   'weight_first',
#   'chloride_first',
#   'creatinine_first'): 0.2174695807534544,
#  ('tco2_first',
#   'weight_first',
#   'chloride_first',
#   'platelet_first',
#   'creatinine_first'): 0.2174695807534544,
#  ('tco2_first',
#   'weight_first',
#   'chloride_first',
#   'creatinine_first',
#   'platelet_first'): 0.21746014123794383,
#  ('tco2_first',
#   'weight_first',
#   'platelet_first',
#   'chloride_first'): 0.21749984990337803,
#  ('tco2_first',
#   'weight_first',
#   'platelet_first',
#   'creatinine_first'): 0.2174695807534544,
#  ('tco2_first',
#   'weight_first',
#   'platelet_first',
#   'chloride_first',
#   'creatinine_first'): 0.2174695807534544,
#  ('tco2_first',
#   'weight_first',
#   'platelet_first',
#   'creatinine_first',
#   'chloride_first'): 0.21749984990337803,
#  ('tco2_first', 'platelet_first', 'weight_first'): 0.21750517250991813,
#  ('tco2_first', 'platelet_first', 'chloride_first'): 0.21749984990337803,
#  ('tco2_first', 'platelet_first', 'creatinine_first'): 0.2174695807534544,
#  ('tco2_first',
#   'platelet_first',
#   'chloride_first',
#   'weight_first'): 0.030822679199130214,
#  ('tco2_first',
#   'platelet_first',
#   'chloride_first',
#   'creatinine_first'): 0.3815006413621993,
#  ('tco2_first',
#   'platelet_first',
#   'chloride_first',
#   'creatinine_first',
#   'weight_first'): 0.21750517250991813,
#  ('tco2_first',
#   'platelet_first',
#   'chloride_first',
#   'weight_first',
#   'creatinine_first'): 0.2174695807534544,
#  ('tco2_first',
#   'platelet_first',
#   'weight_first',
#   'chloride_first'): 0.21749984990337803,
#  ('tco2_first',
#   'platelet_first',
#   'weight_first',
#   'creatinine_first'): 0.2174695807534544,
#  ('tco2_first',
#   'platelet_first',
#   'weight_first',
#   'chloride_first',
#   'creatinine_first'): 0.2174695807534544,
#  ('tco2_first',
#   'platelet_first',
#   'weight_first',
#   'creatinine_first',
#   'chloride_first'): 0.21749984990337803,
#  ('tco2_first',
#   'platelet_first',
#   'creatinine_first',
#   'weight_first'): 0.21750517250991813,
#  ('tco2_first',
#   'platelet_first',
#   'creatinine_first',
#   'chloride_first'): 0.21749984990337803,
#  ('tco2_first',
#   'platelet_first',
#   'creatinine_first',
#   'chloride_first',
#   'weight_first'): 0.21750517250991813,
#  ('tco2_first',
#   'platelet_first',
#   'creatinine_first',
#   'weight_first',
#   'chloride_first'): 0.21749984990337803,
#  ('tco2_first', 'creatinine_first', 'weight_first'): 0.21750517250991813,
#  ('tco2_first', 'creatinine_first', 'platelet_first'): 0.21746014123794383,
#  ('tco2_first', 'creatinine_first', 'chloride_first'): 0.21749984990337803,
#  ('tco2_first',
#   'creatinine_first',
#   'chloride_first',
#   'weight_first'): 0.0022451953927903265,
#  ('tco2_first',
#   'creatinine_first',
#   'chloride_first',
#   'platelet_first'): 0.3815473963678177,
#  ('tco2_first',
#   'creatinine_first',
#   'chloride_first',
#   'platelet_first',
#   'weight_first'): 0.21750517250991813,
#  ('tco2_first',
#   'creatinine_first',
#   'chloride_first',
#   'weight_first',
#   'platelet_first'): 0.21746014123794383,
#  ('tco2_first',
#   'creatinine_first',
#   'weight_first',
#   'platelet_first'): 0.11546389324150266,
#  ('tco2_first',
#   'creatinine_first',
#   'weight_first',
#   'chloride_first'): 0.11542815583003466,
#  ('tco2_first',
#   'creatinine_first',
#   'weight_first',
#   'chloride_first',
#   'platelet_first'): 0.21746014123794383,
#  ('tco2_first',
#   'creatinine_first',
#   'weight_first',
#   'platelet_first',
#   'chloride_first'): 0.21749984990337803,
#  ('tco2_first',
#   'creatinine_first',
#   'platelet_first',
#   'weight_first'): 0.21750517250991813,
#  ('tco2_first',
#   'creatinine_first',
#   'platelet_first',
#   'chloride_first'): 0.21749984990337803,
#  ('tco2_first',
#   'creatinine_first',
#   'platelet_first',
#   'chloride_first',
#   'weight_first'): 0.21750517250991813,
#  ('tco2_first',
#   'creatinine_first',
#   'platelet_first',
#   'weight_first',
#   'chloride_first'): 0.21749984990337803,
#  ('chloride_first', 'weight_first'): 0.21750517250991813,
#  ('chloride_first', 'platelet_first'): 0.21746014123794383,
#  ('chloride_first', 'tco2_first'): 0.217430099431202,
#  ('chloride_first', 'creatinine_first'): 0.2174695807534544,
#  ('chloride_first', 'tco2_first', 'weight_first'): 0.0019463368927770917,
#  ('chloride_first', 'tco2_first', 'platelet_first'): 0.10580965551464167,
#  ('chloride_first', 'tco2_first', 'creatinine_first'): 0.0018230196904496375,
#  ('chloride_first',
#   'tco2_first',
#   'platelet_first',
#   'weight_first'): 0.030822679199130214,
#  ('chloride_first',
#   'tco2_first',
#   'platelet_first',
#   'creatinine_first'): 0.3815006413621993,
#  ('chloride_first',
#   'tco2_first',
#   'platelet_first',
#   'creatinine_first',
#   'weight_first'): 0.21750517250991813,
#  ('chloride_first',
#   'tco2_first',
#   'platelet_first',
#   'weight_first',
#   'creatinine_first'): 0.2174695807534544,
#  ('chloride_first',
#   'tco2_first',
#   'weight_first',
#   'platelet_first'): 0.21746014123794383,
#  ('chloride_first',
#   'tco2_first',
#   'weight_first',
#   'creatinine_first'): 0.2174695807534544,
#  ('chloride_first',
#   'tco2_first',
#   'weight_first',
#   'platelet_first',
#   'creatinine_first'): 0.19640036277660688,
#  ('chloride_first',
#   'tco2_first',
#   'weight_first',
#   'creatinine_first',
#   'platelet_first'): 0.19637517218348843,
#  ('chloride_first',
#   'tco2_first',
#   'creatinine_first',
#   'weight_first'): 0.21750517250991813,
#  ('chloride_first',
#   'tco2_first',
#   'creatinine_first',
#   'platelet_first'): 0.19637517218348843,
#  ('chloride_first',
#   'tco2_first',
#   'creatinine_first',
#   'weight_first',
#   'platelet_first'): 0.03792887133050398,
#  ('chloride_first',
#   'tco2_first',
#   'creatinine_first',
#   'platelet_first',
#   'weight_first'): 0.03792742815521153,
#  ('chloride_first', 'weight_first', 'platelet_first'): 0.03792887133050398,
#  ('chloride_first', 'weight_first', 'tco2_first'): 0.03791736103158807,
#  ('chloride_first', 'weight_first', 'creatinine_first'): 0.2174695807534544,
#  ('chloride_first',
#   'weight_first',
#   'creatinine_first',
#   'platelet_first'): 0.017778465881848893,
#  ('chloride_first',
#   'weight_first',
#   'creatinine_first',
#   'tco2_first'): 0.0021173968211123553,
#  ('chloride_first',
#   'weight_first',
#   'creatinine_first',
#   'platelet_first',
#   'tco2_first'): 0.217430099431202,
#  ('chloride_first',
#   'weight_first',
#   'creatinine_first',
#   'tco2_first',
#   'platelet_first'): 0.21746014123794383,
#  ('chloride_first',
#   'weight_first',
#   'tco2_first',
#   'platelet_first'): 0.21746014123794383,
#  ('chloride_first',
#   'weight_first',
#   'tco2_first',
#   'creatinine_first'): 0.2174695807534544,
#  ('chloride_first',
#   'weight_first',
#   'tco2_first',
#   'platelet_first',
#   'creatinine_first'): 0.2174695807534544,
#  ('chloride_first',
#   'weight_first',
#   'tco2_first',
#   'creatinine_first',
#   'platelet_first'): 0.21746014123794383,
#  ('chloride_first',
#   'weight_first',
#   'platelet_first',
#   'tco2_first'): 0.217430099431202,
#  ('chloride_first',
#   'weight_first',
#   'platelet_first',
#   'creatinine_first'): 0.2174695807534544,
#  ('chloride_first',
#   'weight_first',
#   'platelet_first',
#   'tco2_first',
#   'creatinine_first'): 0.2174695807534544,
#  ('chloride_first',
#   'weight_first',
#   'platelet_first',
#   'creatinine_first',
#   'tco2_first'): 0.217430099431202,
#  ('chloride_first', 'platelet_first', 'weight_first'): 0.21750517250991813,
#  ('chloride_first', 'platelet_first', 'tco2_first'): 0.217430099431202,
#  ('chloride_first', 'platelet_first', 'creatinine_first'): 0.2174695807534544,
#  ('chloride_first',
#   'platelet_first',
#   'tco2_first',
#   'weight_first'): 0.030822679199130214,
#  ('chloride_first',
#   'platelet_first',
#   'tco2_first',
#   'creatinine_first'): 0.3815006413621993,
#  ('chloride_first',
#   'platelet_first',
#   'tco2_first',
#   'creatinine_first',
#   'weight_first'): 0.21750517250991813,
#  ('chloride_first',
#   'platelet_first',
#   'tco2_first',
#   'weight_first',
#   'creatinine_first'): 0.2174695807534544,
#  ('chloride_first',
#   'platelet_first',
#   'weight_first',
#   'tco2_first'): 0.217430099431202,
#  ('chloride_first',
#   'platelet_first',
#   'weight_first',
#   'creatinine_first'): 0.2174695807534544,
#  ('chloride_first',
#   'platelet_first',
#   'weight_first',
#   'tco2_first',
#   'creatinine_first'): 0.2174695807534544,
#  ('chloride_first',
#   'platelet_first',
#   'weight_first',
#   'creatinine_first',
#   'tco2_first'): 0.217430099431202,
#  ('chloride_first',
#   'platelet_first',
#   'creatinine_first',
#   'weight_first'): 0.21750517250991813,
#  ('chloride_first',
#   'platelet_first',
#   'creatinine_first',
#   'tco2_first'): 0.217430099431202,
#  ('chloride_first',
#   'platelet_first',
#   'creatinine_first',
#   'tco2_first',
#   'weight_first'): 0.21750517250991813,
#  ('chloride_first',
#   'platelet_first',
#   'creatinine_first',
#   'weight_first',
#   'tco2_first'): 0.217430099431202,
#  ('chloride_first', 'creatinine_first', 'weight_first'): 0.21750517250991813,
#  ('chloride_first', 'creatinine_first', 'platelet_first'): 0.21746014123794383,
#  ('chloride_first', 'creatinine_first', 'tco2_first'): 0.217430099431202,
#  ('chloride_first',
#   'creatinine_first',
#   'tco2_first',
#   'weight_first'): 0.0022451953927903265,
#  ('chloride_first',
#   'creatinine_first',
#   'tco2_first',
#   'platelet_first'): 0.3815473963678177,
#  ('chloride_first',
#   'creatinine_first',
#   'tco2_first',
#   'platelet_first',
#   'weight_first'): 0.21750517250991813,
#  ('chloride_first',
#   'creatinine_first',
#   'tco2_first',
#   'weight_first',
#   'platelet_first'): 0.21746014123794383,
#  ('chloride_first',
#   'creatinine_first',
#   'weight_first',
#   'platelet_first'): 0.11546389324150266,
#  ('chloride_first',
#   'creatinine_first',
#   'weight_first',
#   'tco2_first'): 0.1154483947839156,
#  ('chloride_first',
#   'creatinine_first',
#   'weight_first',
#   'tco2_first',
#   'platelet_first'): 0.21746014123794383,
#  ('chloride_first',
#   'creatinine_first',
#   'weight_first',
#   'platelet_first',
#   'tco2_first'): 0.217430099431202,
#  ('chloride_first',
#   'creatinine_first',
#   'platelet_first',
#   'weight_first'): 0.21750517250991813,
#  ('chloride_first',
#   'creatinine_first',
#   'platelet_first',
#   'tco2_first'): 0.217430099431202,
#  ('chloride_first',
#   'creatinine_first',
#   'platelet_first',
#   'tco2_first',
#   'weight_first'): 0.21750517250991813,
#  ('chloride_first',
#   'creatinine_first',
#   'platelet_first',
#   'weight_first',
#   'tco2_first'): 0.217430099431202,
#  ('creatinine_first', 'weight_first'): 0.21750517250991813,
#  ('creatinine_first', 'platelet_first'): 0.21746014123794383,
#  ('creatinine_first', 'tco2_first'): 0.217430099431202,
#  ('creatinine_first', 'chloride_first'): 0.21749984990337803,
#  ('creatinine_first', 'tco2_first', 'weight_first'): 0.0004463599655295373,
#  ('creatinine_first', 'tco2_first', 'platelet_first'): 0.16570706050334397,
#  ('creatinine_first', 'tco2_first', 'chloride_first'): 0.001784300668466628,
#  ('creatinine_first',
#   'tco2_first',
#   'platelet_first',
#   'weight_first'): 0.0658457896396117,
#  ('creatinine_first',
#   'tco2_first',
#   'platelet_first',
#   'chloride_first'): 0.38145822518474326,
#  ('creatinine_first',
#   'tco2_first',
#   'platelet_first',
#   'chloride_first',
#   'weight_first'): 0.21750517250991813,
#  ('creatinine_first',
#   'tco2_first',
#   'platelet_first',
#   'weight_first',
#   'chloride_first'): 0.21749984990337803,
#  ('creatinine_first',
#   'tco2_first',
#   'chloride_first',
#   'weight_first'): 0.21750517250991813,
#  ('creatinine_first',
#   'tco2_first',
#   'chloride_first',
#   'platelet_first'): 0.21746014123794383,
#  ('creatinine_first',
#   'tco2_first',
#   'chloride_first',
#   'weight_first',
#   'platelet_first'): 0.21746014123794383,
#  ('creatinine_first',
#   'tco2_first',
#   'chloride_first',
#   'platelet_first',
#   'weight_first'): 0.21750517250991813,
#  ('creatinine_first',
#   'tco2_first',
#   'weight_first',
#   'platelet_first'): 0.21746014123794383,
#  ('creatinine_first',
#   'tco2_first',
#   'weight_first',
#   'chloride_first'): 0.21749984990337803,
#  ('creatinine_first',
#   'tco2_first',
#   'weight_first',
#   'chloride_first',
#   'platelet_first'): 0.21746014123794383,
#  ('creatinine_first',
#   'tco2_first',
#   'weight_first',
#   'platelet_first',
#   'chloride_first'): 0.21749984990337803,
#  ('creatinine_first', 'chloride_first', 'weight_first'): 0.21750517250991813,
#  ('creatinine_first', 'chloride_first', 'platelet_first'): 0.21746014123794383,
#  ('creatinine_first', 'chloride_first', 'tco2_first'): 0.217430099431202,
#  ('creatinine_first',
#   'chloride_first',
#   'tco2_first',
#   'weight_first'): 0.0022451953927903265,
#  ('creatinine_first',
#   'chloride_first',
#   'tco2_first',
#   'platelet_first'): 0.3815473963678177,
#  ('creatinine_first',
#   'chloride_first',
#   'tco2_first',
#   'platelet_first',
#   'weight_first'): 0.21750517250991813,
#  ('creatinine_first',
#   'chloride_first',
#   'tco2_first',
#   'weight_first',
#   'platelet_first'): 0.21746014123794383,
#  ('creatinine_first',
#   'chloride_first',
#   'weight_first',
#   'platelet_first'): 0.11546389324150266,
#  ('creatinine_first',
#   'chloride_first',
#   'weight_first',
#   'tco2_first'): 0.1154483947839156,
#  ('creatinine_first',
#   'chloride_first',
#   'weight_first',
#   'tco2_first',
#   'platelet_first'): 0.21746014123794383,
#  ('creatinine_first',
#   'chloride_first',
#   'weight_first',
#   'platelet_first',
#   'tco2_first'): 0.217430099431202,
#  ('creatinine_first',
#   'chloride_first',
#   'platelet_first',
#   'weight_first'): 0.21750517250991813,
#  ('creatinine_first',
#   'chloride_first',
#   'platelet_first',
#   'tco2_first'): 0.217430099431202,
#  ('creatinine_first',
#   'chloride_first',
#   'platelet_first',
#   'tco2_first',
#   'weight_first'): 0.21750517250991813,
#  ('creatinine_first',
#   'chloride_first',
#   'platelet_first',
#   'weight_first',
#   'tco2_first'): 0.217430099431202,
#  ('creatinine_first', 'weight_first', 'platelet_first'): 0.21746014123794383,
#  ('creatinine_first', 'weight_first', 'tco2_first'): 0.217430099431202,
#  ('creatinine_first', 'weight_first', 'chloride_first'): 0.21749984990337803,
#  ('creatinine_first',
#   'weight_first',
#   'tco2_first',
#   'platelet_first'): 0.06584331541618448,
#  ('creatinine_first',
#   'weight_first',
#   'tco2_first',
#   'chloride_first'): 0.002116556614446923,
#  ('creatinine_first',
#   'weight_first',
#   'tco2_first',
#   'platelet_first',
#   'chloride_first'): 0.21749984990337803,
#  ('creatinine_first',
#   'weight_first',
#   'tco2_first',
#   'chloride_first',
#   'platelet_first'): 0.21746014123794383,
#  ('creatinine_first',
#   'weight_first',
#   'chloride_first',
#   'platelet_first'): 0.21746014123794383,
#  ('creatinine_first',
#   'weight_first',
#   'chloride_first',
#   'tco2_first'): 0.217430099431202,
#  ('creatinine_first',
#   'weight_first',
#   'chloride_first',
#   'tco2_first',
#   'platelet_first'): 0.21746014123794383,
#  ('creatinine_first',
#   'weight_first',
#   'chloride_first',
#   'platelet_first',
#   'tco2_first'): 0.217430099431202,
#  ('creatinine_first',
#   'weight_first',
#   'platelet_first',
#   'tco2_first'): 0.217430099431202,
#  ('creatinine_first',
#   'weight_first',
#   'platelet_first',
#   'chloride_first'): 0.21749984990337803,
#  ('creatinine_first',
#   'weight_first',
#   'platelet_first',
#   'tco2_first',
#   'chloride_first'): 0.21749984990337803,
#  ('creatinine_first',
#   'weight_first',
#   'platelet_first',
#   'chloride_first',
#   'tco2_first'): 0.217430099431202,
#  ('creatinine_first', 'platelet_first', 'weight_first'): 0.21750517250991813,
#  ('creatinine_first', 'platelet_first', 'tco2_first'): 0.217430099431202,
#  ('creatinine_first', 'platelet_first', 'chloride_first'): 0.21749984990337803,
#  ('creatinine_first',
#   'platelet_first',
#   'tco2_first',
#   'weight_first'): 0.0658457896396117,
#  ('creatinine_first',
#   'platelet_first',
#   'tco2_first',
#   'chloride_first'): 0.38145822518474326,
#  ('creatinine_first',
#   'platelet_first',
#   'tco2_first',
#   'chloride_first',
#   'weight_first'): 0.21750517250991813,
#  ('creatinine_first',
#   'platelet_first',
#   'tco2_first',
#   'weight_first',
#   'chloride_first'): 0.21749984990337803,
#  ('creatinine_first',
#   'platelet_first',
#   'chloride_first',
#   'weight_first'): 0.21750517250991813,
#  ('creatinine_first',
#   'platelet_first',
#   'chloride_first',
#   'tco2_first'): 0.217430099431202,
#  ('creatinine_first',
#   'platelet_first',
#   'chloride_first',
#   'tco2_first',
#   'weight_first'): 0.21750517250991813,
#  ('creatinine_first',
#   'platelet_first',
#   'chloride_first',
#   'weight_first',
#   'tco2_first'): 0.217430099431202,
#  ('creatinine_first',
#   'platelet_first',
#   'weight_first',
#   'tco2_first'): 0.217430099431202,
#  ('creatinine_first',
#   'platelet_first',
#   'weight_first',
#   'chloride_first'): 0.21749984990337803,
#  ('creatinine_first',
#   'platelet_first',
#   'weight_first',
#   'tco2_first',
#   'chloride_first'): 0.21749984990337803,
#  ('creatinine_first',
#   'platelet_first',
#   'weight_first',
#   'chloride_first',
#   'tco2_first'): 0.217430099431202,
#  ('weight_first', 'platelet_first'): 0.21746014123794383,
#  ('weight_first', 'tco2_first'): 0.217430099431202,
#  ('weight_first', 'chloride_first'): 0.21749984990337803,
#  ('weight_first', 'creatinine_first'): 0.2174695807534544,
#  ('weight_first', 'tco2_first', 'platelet_first'): 0.004165598373760196,
#  ('weight_first', 'tco2_first', 'chloride_first'): 0.0019392094340996906,
#  ('weight_first', 'tco2_first', 'creatinine_first'): 0.0004473433412838353,
#  ('weight_first',
#   'tco2_first',
#   'platelet_first',
#   'chloride_first'): 0.030831078329680472,
#  ('weight_first',
#   'tco2_first',
#   'platelet_first',
#   'creatinine_first'): 0.06586838738128672,
#  ('weight_first',
#   'tco2_first',
#   'platelet_first',
#   'creatinine_first',
#   'chloride_first'): 0.21749984990337803,
#  ('weight_first',
#   'tco2_first',
#   'platelet_first',
#   'chloride_first',
#   'creatinine_first'): 0.2174695807534544,
#  ('weight_first',
#   'tco2_first',
#   'chloride_first',
#   'platelet_first'): 0.21746014123794383,
#  ('weight_first',
#   'tco2_first',
#   'chloride_first',
#   'creatinine_first'): 0.2174695807534544,
#  ('weight_first',
#   'tco2_first',
#   'chloride_first',
#   'platelet_first',
#   'creatinine_first'): 0.2174695807534544,
#  ('weight_first',
#   'tco2_first',
#   'chloride_first',
#   'creatinine_first',
#   'platelet_first'): 0.21746014123794383,
#  ('weight_first',
#   'tco2_first',
#   'creatinine_first',
#   'platelet_first'): 0.21746014123794383,
#  ('weight_first',
#   'tco2_first',
#   'creatinine_first',
#   'chloride_first'): 0.21749984990337803,
#  ('weight_first',
#   'tco2_first',
#   'creatinine_first',
#   'chloride_first',
#   'platelet_first'): 0.2130153963111007,
#  ('weight_first',
#   'tco2_first',
#   'creatinine_first',
#   'platelet_first',
#   'chloride_first'): 0.21305787969532225,
#  ('weight_first', 'chloride_first', 'platelet_first'): 0.2130153963111007,
#  ('weight_first', 'chloride_first', 'tco2_first'): 0.2129879203089048,
#  ('weight_first', 'chloride_first', 'creatinine_first'): 0.2174695807534544,
#  ('weight_first',
#   'chloride_first',
#   'creatinine_first',
#   'platelet_first'): 0.017778465881848893,
#  ('weight_first',
#   'chloride_first',
#   'creatinine_first',
#   'tco2_first'): 0.0021173968211123553,
#  ('weight_first',
#   'chloride_first',
#   'creatinine_first',
#   'platelet_first',
#   'tco2_first'): 0.217430099431202,
#  ('weight_first',
#   'chloride_first',
#   'creatinine_first',
#   'tco2_first',
#   'platelet_first'): 0.21746014123794383,
#  ('weight_first',
#   'chloride_first',
#   'tco2_first',
#   'platelet_first'): 0.21746014123794383,
#  ('weight_first',
#   'chloride_first',
#   'tco2_first',
#   'creatinine_first'): 0.2174695807534544,
#  ('weight_first',
#   'chloride_first',
#   'tco2_first',
#   'platelet_first',
#   'creatinine_first'): 0.2174695807534544,
#  ('weight_first',
#   'chloride_first',
#   'tco2_first',
#   'creatinine_first',
#   'platelet_first'): 0.21746014123794383,
#  ('weight_first',
#   'chloride_first',
#   'platelet_first',
#   'tco2_first'): 0.217430099431202,
#  ('weight_first',
#   'chloride_first',
#   'platelet_first',
#   'creatinine_first'): 0.2174695807534544,
#  ('weight_first',
#   'chloride_first',
#   'platelet_first',
#   'tco2_first',
#   'creatinine_first'): 0.2174695807534544,
#  ('weight_first',
#   'chloride_first',
#   'platelet_first',
#   'creatinine_first',
#   'tco2_first'): 0.217430099431202,
#  ('weight_first', 'platelet_first', 'tco2_first'): 0.217430099431202,
#  ('weight_first', 'platelet_first', 'chloride_first'): 0.21749984990337803,
#  ('weight_first', 'platelet_first', 'creatinine_first'): 0.2174695807534544,
#  ('weight_first',
#   'platelet_first',
#   'tco2_first',
#   'chloride_first'): 0.030831078329680472,
#  ('weight_first',
#   'platelet_first',
#   'tco2_first',
#   'creatinine_first'): 0.06586838738128672,
#  ('weight_first',
#   'platelet_first',
#   'tco2_first',
#   'creatinine_first',
#   'chloride_first'): 0.21749984990337803,
#  ('weight_first',
#   'platelet_first',
#   'tco2_first',
#   'chloride_first',
#   'creatinine_first'): 0.2174695807534544,
#  ('weight_first',
#   'platelet_first',
#   'chloride_first',
#   'tco2_first'): 0.217430099431202,
#  ('weight_first',
#   'platelet_first',
#   'chloride_first',
#   'creatinine_first'): 0.2174695807534544,
#  ('weight_first',
#   'platelet_first',
#   'chloride_first',
#   'tco2_first',
#   'creatinine_first'): 0.2174695807534544,
#  ('weight_first',
#   'platelet_first',
#   'chloride_first',
#   'creatinine_first',
#   'tco2_first'): 0.217430099431202,
#  ('weight_first',
#   'platelet_first',
#   'creatinine_first',
#   'tco2_first'): 0.217430099431202,
#  ('weight_first',
#   'platelet_first',
#   'creatinine_first',
#   'chloride_first'): 0.21749984990337803,
#  ('weight_first',
#   'platelet_first',
#   'creatinine_first',
#   'tco2_first',
#   'chloride_first'): 0.21749984990337803,
#  ('weight_first',
#   'platelet_first',
#   'creatinine_first',
#   'chloride_first',
#   'tco2_first'): 0.217430099431202,
#  ('weight_first', 'creatinine_first', 'platelet_first'): 0.21746014123794383,
#  ('weight_first', 'creatinine_first', 'tco2_first'): 0.217430099431202,
#  ('weight_first', 'creatinine_first', 'chloride_first'): 0.21749984990337803,
#  ('weight_first',
#   'creatinine_first',
#   'tco2_first',
#   'platelet_first'): 0.06584331541618448,
#  ('weight_first',
#   'creatinine_first',
#   'tco2_first',
#   'chloride_first'): 0.002116556614446923,
#  ('weight_first',
#   'creatinine_first',
#   'tco2_first',
#   'platelet_first',
#   'chloride_first'): 0.21749984990337803,
#  ('weight_first',
#   'creatinine_first',
#   'tco2_first',
#   'chloride_first',
#   'platelet_first'): 0.21746014123794383,
#  ('weight_first',
#   'creatinine_first',
#   'chloride_first',
#   'platelet_first'): 0.21746014123794383,
#  ('weight_first',
#   'creatinine_first',
#   'chloride_first',
#   'tco2_first'): 0.217430099431202,
#  ('weight_first',
#   'creatinine_first',
#   'chloride_first',
#   'tco2_first',
#   'platelet_first'): 0.21746014123794383,
#  ('weight_first',
#   'creatinine_first',
#   'chloride_first',
#   'platelet_first',
#   'tco2_first'): 0.217430099431202,
#  ('weight_first',
#   'creatinine_first',
#   'platelet_first',
#   'tco2_first'): 0.217430099431202,
#  ('weight_first',
#   'creatinine_first',
#   'platelet_first',
#   'chloride_first'): 0.21749984990337803,
#  ('weight_first',
#   'creatinine_first',
#   'platelet_first',
#   'tco2_first',
#   'chloride_first'): 0.21749984990337803,
#  ('weight_first',
#   'creatinine_first',
#   'platelet_first',
#   'chloride_first',
#   'tco2_first'): 0.217430099431202}

# %%
converter = {
    "weight_first": "Weight",
    "platelet_first": "Platelet",
    "tco2_first": "TCO2",
    "chloride_first": "Chloride",
    "creatinine_first": "Creatinine",
}
temp = [
    ((str(i), ", ".join([converter[z] for z in x])), x, y)
    for i, (x, y) in enumerate(res.items())
]

# %%
counts = [1, 5, 4, 3, 2, 1, 1, 2, 1, 1, 2, 1, 1]
count_expanded = []
for i in range(len(counts)):
    count_expanded += [i] * counts[i]

# %%
temp_2 = [(x, y) for x, y in zip(count_expanded, temp)]

# %%
temp_2
# Out:
# [(0, (('0', ''), (), 9.042861906878263e-05)),
#  (1, (('1', 'Weight'), ('weight_first',), 7.175638760592074e-05)),
#  (1, (('2', 'Platelet'), ('platelet_first',), 0.002863131189964069)),
#  (1, (('3', 'TCO2'), ('tco2_first',), 0.00032398194956892104)),
#  (1, (('4', 'Chloride'), ('chloride_first',), 0.00019904045421525722)),
#  (1, (('5', 'Creatinine'), ('creatinine_first',), 0.00016466249826343641)),
#  (2,
#   (('6', 'Platelet, Weight'),
#    ('platelet_first', 'weight_first'),
#    0.0011387710306409436)),
#  (2,
#   (('7', 'Platelet, TCO2'),
#    ('platelet_first', 'tco2_first'),
#    0.014325008126373329)),
#  (2,
#   (('8', 'Platelet, Chloride'),
#    ('platelet_first', 'chloride_first'),
#    0.007509208475529455)),
#  (2,
#   (('9', 'Platelet, Creatinine'),
#    ('platelet_first', 'creatinine_first'),
#    0.015019129499198872)),
#  (3,
#   (('10', 'Platelet, Creatinine, Weight'),
#    ('platelet_first', 'creatinine_first', 'weight_first'),
#    0.00650501543751181)),
#  (3,
#   (('11', 'Platelet, Creatinine, TCO2'),
#    ('platelet_first', 'creatinine_first', 'tco2_first'),
#    0.16570695485004192)),
#  (3,
#   (('12', 'Platelet, Creatinine, Chloride'),
#    ('platelet_first', 'creatinine_first', 'chloride_first'),
#    0.035634173449230616)),
#  (4,
#   (('13', 'Platelet, Creatinine, TCO2, Weight'),
#    ('platelet_first', 'creatinine_first', 'tco2_first', 'weight_first'),
#    0.0658457896396117)),
#  (4,
#   (('14', 'Platelet, Creatinine, TCO2, Chloride'),
#    ('platelet_first', 'creatinine_first', 'tco2_first', 'chloride_first'),
#    0.38145822518474326)),
#  (5,
#   (('15', 'Platelet, Creatinine, TCO2, Chloride, Weight'),
#    ('platelet_first',
#     'creatinine_first',
#     'tco2_first',
#     'chloride_first',
#     'weight_first'),
#    0.21750517250991813)),
#  (6,
#   (('16', 'Platelet, Creatinine, TCO2, Weight, Chloride'),
#    ('platelet_first',
#     'creatinine_first',
#     'tco2_first',
#     'weight_first',
#     'chloride_first'),
#    0.21749984990337803)),
#  (7,
#   (('17', 'Platelet, Creatinine, Chloride, Weight'),
#    ('platelet_first', 'creatinine_first', 'chloride_first', 'weight_first'),
#    0.21750517250991813)),
#  (7,
#   (('18', 'Platelet, Creatinine, Chloride, TCO2'),
#    ('platelet_first', 'creatinine_first', 'chloride_first', 'tco2_first'),
#    0.217430099431202)),
#  (8,
#   (('19', 'Platelet, Creatinine, Chloride, TCO2, Weight'),
#    ('platelet_first',
#     'creatinine_first',
#     'chloride_first',
#     'tco2_first',
#     'weight_first'),
#    0.21750517250991813)),
#  (9,
#   (('20', 'Platelet, Creatinine, Chloride, Weight, TCO2'),
#    ('platelet_first',
#     'creatinine_first',
#     'chloride_first',
#     'weight_first',
#     'tco2_first'),
#    0.217430099431202)),
#  (10,
#   (('21', 'Platelet, Creatinine, Weight, TCO2'),
#    ('platelet_first', 'creatinine_first', 'weight_first', 'tco2_first'),
#    0.217430099431202)),
#  (10,
#   (('22', 'Platelet, Creatinine, Weight, Chloride'),
#    ('platelet_first', 'creatinine_first', 'weight_first', 'chloride_first'),
#    0.21749984990337803)),
#  (11,
#   (('23', 'Platelet, Creatinine, Weight, TCO2, Chloride'),
#    ('platelet_first',
#     'creatinine_first',
#     'weight_first',
#     'tco2_first',
#     'chloride_first'),
#    0.21749984990337803)),
#  (12,
#   (('24', 'Platelet, Creatinine, Weight, Chloride, TCO2'),
#    ('platelet_first',
#     'creatinine_first',
#     'weight_first',
#     'chloride_first',
#     'tco2_first'),
#    0.217430099431202))]

# %%
dot = graphviz.Digraph(comment="Search Visualization")
dot
max = 20

for stage in range(1, 10):
    if stage > 1:
        dot.node(
            f"cluster_{stage}",
            label=f"Search Stage {stage-1}",
            style="filled",
            color="lightgrey",
            shape="box",
        )
    else:
        dot.node(
            f"cluster_{stage}",
            label=f"Search Stage {stage-1}",
            color="lightgrey",
            shape="box",
            style="invis",
        )

    if stage > 1:
        dot.body.append(f'"cluster_{stage-1}" -> "cluster_{stage}" [style=invis]\n')

for stage, ((i, x), y, z) in temp_2[:max]:
    if stage == 0:
        dot.node(str(y), "Initial Value")
    else:
        dot.node(str(y), x + "\nScore: " + format(z, "f"))
    if len(y) > 0:
        dot.edge(str(y[:-1]), str(y))
    for sub_stage, ((sub_i, sub_x), sub_y, sub_z) in temp_2[:max]:
        if stage < sub_stage:
            dot.body.append(f'"{str(y)}" -> "{str(sub_y)}" [style=invis]\n')
            break

dot.attr(layout="dot")
# dot.attr(rankdir='LR')
# dot.attr(ranksep='30')
dot.render("doctest-output/round-table.gv").replace("\\", "/")
"doctest-output/round-table.gv.pdf"
# Out:
# 'doctest-output/round-table.gv.pdf'
